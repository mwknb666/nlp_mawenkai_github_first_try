# %%
print("你好！这是我的第一个Jupyter Notebook代码")
# 计算简单的数学
result = 5 + 3
print(f"5 + 3 = {result}")
# Out:
#   Cell In[2], line 4
#     print(f"5 + 3 = {result}"）
#                              ^
# SyntaxError: invalid character '）' (U+FF09)
